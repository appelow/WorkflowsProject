# %%
# !nextflow run ./main.nf \
    -profile test,docker,arm \
    -resume
# Out:
# Nextflow 25.04.8 is available - Please consider updating your version to it
#
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `./main.nf` [disturbed_poincare] DSL2 - revision: 8d75f29691
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/leoniechrissi 1.0.0dev
# ------------------------------------------------------
# Input/output options
#   input                     : ./assets/samplesheet_copy.csv
#   outdir                    : results/
#
# Reference genome options
#   genome                    : R64-1-1
#   fasta                     : s3://ngi-igenomes/igenomes//Saccharomyces_cerevisiae/Ensembl/R64-1-1/Sequence/WholeGenomeFasta/genome.fa
#
# Institutional config options
# ...
