# %%
# !nextflow run ./main.nf \
    -profile test,docker,arm \
    -resume
# Out:
# Nextflow 25.04.8 is available - Please consider updating your version to it
#
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `./main.nf` [hopeful_carson] DSL2 - revision: 8d75f29691
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/leoniechrissi 1.0.0dev
# ------------------------------------------------------
# Input/output options
#   input                     : https://raw.githubusercontent.com/nf-core/test-datasets/7f1614baeb0ddf66e60be78c3d9fa55440465ac8/samplesheet/v3.10/samplesheet_test.csv
#   outdir                    : results/
#
# Reference genome options
# ...
